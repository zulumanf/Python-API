# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from pprint import pprint

# configure gmaps api key
gmaps.configure(api_key=g_key)

from matplotlib import figure

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
#csv is named citydata.csv
city_data_vaca_df = pd.read_csv ("/Users/franciscozuluaga/Desktop/upenn-phi-data-pt-12-2020-u-c/upenn-phi-data-pt-12-2020-u-c/06-Python-APIs/Homework/Instructions/starter_code/citydata.csv")

#double check correct csv
city_data_vaca_df.head(100)
# Out:
#     Unnamed: 0          City      Lat       Lng  Max Temp  Humidity  \
# 0            0      Thompson  55.7435  -97.8558    -18.40        63
# 1            1         Kapaa  22.0752 -159.3190     73.40        53
# 2            2         Dinar  38.0650   30.1656     42.80        75
# 3            3   Tuktoyaktuk  69.4541 -133.0374    -27.40        68
# 4            4         Horta  38.5333  -28.6333     60.80        63
# ..         ...           ...      ...       ...       ...       ...
# 95          95  Ponta do Sol  32.6667  -17.1000     60.01        74
# 96          96      Karratha -20.7377  116.8463     84.13        53
# 97          97      Khartoum  15.5518   32.5324     81.00        24
# 98          98         Kumul  42.8000   93.4500     30.06        82
# 99          99         Roald  62.5833    6.1333     23.00        63
#
#     Cloudiness  Wind Speed Country        Date
# 0           75        6.91      CA  1612989184
# 1           20       11.50      US  1612989184
# 2            0        5.75      TR  1612989376
# 3           20       12.66      CA  1612989184
# 4           40       26.46      PT  1612989185
# ..         ...         ...     ...         ...
# 95          83        1.99      PT  1612989219
# 96           0       11.52      AU  1612989220
# 97           0        4.61      SD  1612988954
# 98          99        7.96      CN  1612989221
# 99           0       10.36      NO  1612989221
#
# [100 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#configure gmaps
gmaps.configure(api_key="AIzaSyBmQAXxxigHVompRxX-CcSjkCimaHXQRTg")



base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
#params = {"type" : "hotel",
         # "keyword" : "hotel",
         # "radius" : 5000,
         # "key" : g_key}

# %%
#store latitude and longitude as locations
locations = city_data_vaca_df[["Lat", "Lng"]].astype(float)

#will be used as the weight for the heatmap
humidity = city_data_vaca_df["Humidity"].astype(float)

#plot heatmap
heatmap_fig = gmaps.figure()

#create heat leyer
humidity_layer = gmaps.heatmap_layer(locations, weights = humidity, dissipating = False
                                    , max_intensity = 10, point_radius = 1)
#add layer
heatmap_fig.add_layer(humidity_layer)

#display
heatmap_fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#create new data frame with ideal weather conditions & drop na
ideal_weather_df = city_data_vaca_df.loc[(city_data_vaca_df["Max Temp"] > 65) & (city_data_vaca_df["Max Temp"] < 80)].dropna()

#check to see filter passed
ideal_weather_df.head()
# Out:
#     Unnamed: 0      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1            1     Kapaa  22.0752 -159.3190     73.40        53          20
# 7            7   Ushuaia -54.8000  -68.3000     77.00        27           0
# 12          12   Rikitea -23.1203 -134.9692     78.51        75          20
# 16          16      Doha  25.2867   51.5333     66.20        82           0
# 20          20  Antalaha -14.9003   50.2788     77.27        84         100
#
#     Wind Speed Country        Date
# 1        11.50      US  1612989184
# 7        20.71      AR  1612989301
# 12       13.44      PF  1612989187
# 16        5.75      QA  1612989106
# 20        1.25      MG  1612989188

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#add in hotel name column to the data frame
hotel_df = ideal_weather_df
hotel_df['Hotel Name'] = ""
hotel_df
# Out:
#      Unnamed: 0              City      Lat       Lng  Max Temp  Humidity  \
# 1             1             Kapaa  22.0752 -159.3190     73.40        53
# 7             7           Ushuaia -54.8000  -68.3000     77.00        27
# 12           12           Rikitea -23.1203 -134.9692     78.51        75
# 16           16              Doha  25.2867   51.5333     66.20        82
# 20           20          Antalaha -14.9003   50.2788     77.27        84
# ..          ...               ...      ...       ...       ...       ...
# 555         555  Valle de Allende  26.9333 -105.4000     76.82        16
# 561         561        Manjeshwar  12.7194   74.8861     73.40        83
# 563         563            Noumea -22.2763  166.4572     79.00        94
# 571         571             Kidal  18.4411    1.4078     74.70        16
# 574         574      St. George's  12.0564  -61.7485     78.80        69
#
#      Cloudiness  Wind Speed Country        Date Hotel Name
# 1            20       11.50      US  1612989184
# 7             0       20.71      AR  1612989301
# 12           20       13.44      PF  1612989187
# 16            0        5.75      QA  1612989106
# 20          100        1.25      MG  1612989188
# ..          ...         ...     ...         ...        ...
# 555           0        6.49      MX  1612989372
# 561          82        3.44      IN  1612989373
# 563          75        2.30      NC  1612989199
# 571          18        7.81      ML  1612989375
# 574          40       17.27      GD  1612989375
#
# [177 rows x 11 columns]

# %%
#parameters
params = {"type" : "hotel",
          "keyword" : "hotel",
          "radius" : 5000,
          "key" : g_key}


#base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"


# run a request using our params dictionary
response = requests.get(base_url, params=params)

print(response)
# Out:
# <Response [200]>

# %%
#for loop to get the hotel names for each city, uses latitude and longitude coordinates to get hotels
for index, row in hotel_df.iterrows():
    #get city name, lat, lnt from df
    lat = row["Lat"]
    lng = row["Lng"]
    city_name = row["City"]
    
    params["location"] = f"{lat},{lng}"

    #make API hit
    print(f"Retrieving Results for Index {index}: {city_name}.")
    response = requests.get(base_url, params=params).json()
    
    results = response['results']
    
    #save the hotel to dataframe
    try:
        print(f"Closest hotel in {city_name} is {results[0]['name']}.")
        hotel_df.loc[index, "Hotel Name"] = results[0]['name']

    #skip if no hotel
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")

# Print end of search once searching is completed
print("-------End of Search-------")
# Out:
# Retrieving Results for Index 1: Kapaa.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 7: Ushuaia.
# Closest hotel in Ushuaia is Hotel Los Yámanas.
# ------------
# Retrieving Results for Index 12: Rikitea.
# Closest hotel in Rikitea is Pension Bianca & Benoit.
# ------------
# Retrieving Results for Index 16: Doha.
# Closest hotel in Doha is Mandarin Oriental, Doha.
# ------------
# Retrieving Results for Index 20: Antalaha.
# Closest hotel in Antalaha is Villa-Malaza.
# ------------
# Retrieving Results for Index 21: Kruisfontein.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 23: Banyo.
# Closest hotel in Banyo is Hôtel Municipal de Banyo.
# ------------
# Retrieving Results for Index 25: Hilo.
# Closest hotel in Hilo is Hilo Hawaiian Hotel.
# ------------
# Retrieving Results for Index 26: Anito.
# Closest hotel in Anito is The Yellow House.
# ------------
# Retrieving Results for Index 32: East London.
# Closest hotel in East London is Blue Lagoon Hotel.
# ------------
# Retrieving Results for Index 36: Cape Town.
# Closest hotel in Cape Town is Atlanticview Cape Town Boutique Hotel.
# ------------
# Retrieving Results for Index 39: Vaini.
# Closest hotel in Vaini is Paradise First Hotel.
# ------------
# Retrieving Results for Index 42: Lebu.
# Closest hotel in Lebu is Hotel Plaza Lebu.
# ------------
# Retrieving Results for Index 45: Port Alfred.
# Closest hotel in Port Alfred is Royal St Andrews Hotel.
# ------------
# Retrieving Results for Index 46: Coquimbo.
# Closest hotel in Coquimbo is Enjoy Coquimbo Hotel de la Bahía.
# ------------
# Retrieving Results for Index 51: Sumbe.
# Closest hotel in Sumbe is Hotel Ritz Sumbe.
# ------------
# Retrieving Results for Index 53: Souillac.
# Closest hotel in Souillac is Shanti Maurice Resort & Spa.
# ------------
# Retrieving Results for Index 54: Puerto Ayora.
# Closest hotel in Puerto Ayora is Angermeyer Waterfront Inn.
# ------------
# Retrieving Results for Index 61: Cabatuan.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 64: Machinga.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 65: Castro.
# Closest hotel in Castro is Pousada Rota Dos Tropeiros.
# ------------
# Retrieving Results for Index 67: Punta Arenas.
# Closest hotel in Punta Arenas is Hotel Dreams Del Estrecho.
# ------------
# Retrieving Results for Index 69: Bandarbeyla.
# Closest hotel in Bandarbeyla is JABIR HOTEL.
# ------------
# Retrieving Results for Index 72: Chui.
# Closest hotel in Chui is Bertelli Chuí Hotel.
# ------------
# Retrieving Results for Index 79: Constitución.
# Closest hotel in Constitución is Posada la Piedra.
# ------------
# Retrieving Results for Index 80: Bredasdorp.
# Closest hotel in Bredasdorp is Bredasdorp Country Manor.
# ------------
# Retrieving Results for Index 81: Carnarvon.
# Closest hotel in Carnarvon is Carnarvon Sea Change Apartments.
# ------------
# Retrieving Results for Index 83: Hermanus.
# Closest hotel in Hermanus is Misty Waves Boutique Hotel.
# ------------
# Retrieving Results for Index 84: Beloha.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 87: Mar del Plata.
# Closest hotel in Mar del Plata is Hotel Las Rocas.
# ------------
# Retrieving Results for Index 88: Moindou.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 101: Cabo San Lucas.
# Closest hotel in Cabo San Lucas is Waldorf Astoria Los Cabos Pedregal.
# ------------
# Retrieving Results for Index 103: Padang.
# Closest hotel in Padang is Air Manis Hill Residence.
# ------------
# Retrieving Results for Index 108: Quelimane.
# Closest hotel in Quelimane is Milénio Hotel.
# ------------
# Retrieving Results for Index 110: Mount Isa.
# Closest hotel in Mount Isa is ibis Styles Mt Isa Verona.
# ------------
# Retrieving Results for Index 120: Bambous Virieux.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 123: Vao.
# Closest hotel in Vao is OURE TERA beach resort.
# ------------
# Retrieving Results for Index 129: Truth or Consequences.
# Closest hotel in Truth or Consequences is Sierra Grande Lodge & Spa.
# ------------
# Retrieving Results for Index 131: Salalah.
# Closest hotel in Salalah is HYATT SALALAH HOTEL.
# ------------
# Retrieving Results for Index 134: Atar.
# Closest hotel in Atar is Odar kanawal.
# ------------
# Retrieving Results for Index 136: Cap Malheureux.
# Closest hotel in Cap Malheureux is Mauricia Beachcomber Resort & Spa.
# ------------
# Retrieving Results for Index 141: Marsh Harbour.
# Closest hotel in Marsh Harbour is Abaco Beach Resort.
# ------------
# Retrieving Results for Index 142: Atuona.
# Closest hotel in Atuona is Hôtel Hiva Oa Hanakee Lodge.
# ------------
# Retrieving Results for Index 145: Biak.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 149: Seddon.
# Closest hotel in Seddon is Quest NewQuay, Docklands.
# ------------
# Retrieving Results for Index 150: Mahanje.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 153: Port Blair.
# Closest hotel in Port Blair is Hotel Value Luxury Stay Andaman.
# ------------
# Retrieving Results for Index 156: Mabaruma.
# Closest hotel in Mabaruma is Small's Enterprise.
# ------------
# Retrieving Results for Index 158: Los Llanos de Aridane.
# Closest hotel in Los Llanos de Aridane is Hotel Hacienda de Abajo.
# ------------
# Retrieving Results for Index 159: Mahabalipuram.
# Closest hotel in Mahabalipuram is Radisson Blu Resort Temple Bay Mamallapuram.
# ------------
# Retrieving Results for Index 160: Gulfport.
# Closest hotel in Gulfport is Oasis Resort.
# ------------
# Retrieving Results for Index 161: Sam Phran.
# Closest hotel in Sam Phran is ParnDhevi Riverside Resort & Spa (ปานเทวี ริเวอร์ไซด์ รีสอร์ท แอนด์ สปา).
# ------------
# Retrieving Results for Index 170: Cidreira.
# Closest hotel in Cidreira is Hotel Castelo.
# ------------
# Retrieving Results for Index 173: Emerald.
# Closest hotel in Emerald is Stay On Sullivan.
# ------------
# Retrieving Results for Index 174: Bengkulu.
# Closest hotel in Bengkulu is Mercure Bengkulu.
# ------------
# Retrieving Results for Index 183: Blackwater.
# Closest hotel in Blackwater is The Capricorn Hotel.
# ------------
# Retrieving Results for Index 184: Mataram.
# Closest hotel in Mataram is ASTON Inn Mataram.
# ------------
# Retrieving Results for Index 186: Rafai.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 188: Itambacuri.
# Closest hotel in Itambacuri is Pousada Bela.
# ------------
# Retrieving Results for Index 191: Harper.
# Closest hotel in Harper is Grands' Guesthouse.
# ------------
# Retrieving Results for Index 193: Mwene-Ditu.
# Closest hotel in Mwene-Ditu is Hôtel Kakangayi.
# ------------
# Retrieving Results for Index 195: Port Elizabeth.
# Closest hotel in Port Elizabeth is Island Way Villa.
# ------------
# Retrieving Results for Index 196: Colesberg.
# Closest hotel in Colesberg is The Barracks.
# ------------
# Retrieving Results for Index 198: Demba.
# Missing field/result... skipping.
# ------------
# Retrieving Results for Index 199: Luwuk.
# Closest hotel in Luwuk is Swiss-Belinn Hotel Luwuk.
# ------------
# Retrieving Results for Index 201: Hambantota.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/http/client.py in getresponse(self)
#    1353             try:
# -> 1354                 response.begin()
#    1355             except ConnectionError:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/http/client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/ssl.py in read(self, len, buffer)
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/ssl.py in read(self, len, buffer)
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#
# OSError: [Errno 65] No route to host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     726             retries = retries.increment(
# --> 727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     728             )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     409             if read is False or not self._is_method_retryable(method):
# --> 410                 raise six.reraise(type(error), error, _stacktrace)
#     411             elif read is not None:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/http/client.py in getresponse(self)
#    1353             try:
# -> 1354                 response.begin()
#    1355             except ConnectionError:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/http/client.py in begin(self)
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/http/client.py in _read_status(self)
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/ssl.py in read(self, len, buffer)
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/ssl.py in read(self, len, buffer)
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#
# ProtocolError: ('Connection aborted.', OSError(65, 'No route to host'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-401-e3fdd0bf15b1> in <module>
#      10     #make API hit
#      11     print(f"Retrieving Results for Index {index}: {city_name}.")
# ---> 12     response = requests.get(base_url, params=params).json()
#      13
#      14     results = response['results']
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', OSError(65, 'No route to host'))

# %%
#export hotel into csv and drop na
hotel_df.dropna()
hotel_df.to_csv('hotel_export.csv')

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
#define layers
map_markers = gmaps.marker_layer(locations)

#add layers onto map
fig.add_layer(map_markers)

#display map
fig

# Display Map
# Out:
# Figure(layout=FigureLayout(height='420px'))
